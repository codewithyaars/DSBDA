# %% [markdown]
# # Part - 1 (age and income)

# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
df=pd.read_csv('dsbda 3 adult.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       90                 ?   77053       HS-grad              9
# 1       82           Private  132870       HS-grad              9
# 2       66                 ?  186061  Some-college             10
# 3       54           Private  140359       7th-8th              4
# 4       41           Private  264663  Some-college             10
# 5       34           Private  216864       HS-grad              9
# 6       38           Private  150601          10th              6
# 7       74         State-gov   88638     Doctorate             16
# 8       68       Federal-gov  422013       HS-grad              9
# 9       41           Private   70037  Some-college             10
# 10      45           Private  172274     Doctorate             16
# 11      38  Self-emp-not-inc  164526   Prof-school             15
# 12      52           Private  129177     Bachelors             13
# ...

# %%
print(df.shape)
# Out:
# (32561, 15)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital.gain      32561 non-null int64
# capital.loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
df.mean()
# Out:
# age                   38.581647
# fnlwgt            189778.366512
# education.num         10.080679
# capital.gain        1077.648844
# capital.loss          87.303830
# hours.per.week        40.437456
# dtype: float64

# %%
print(df.loc[:,'age'].mean())
# Out:
# 38.58164675532078

# %%
df.mean(axis=1)[0:5]
# Out:
# 0    13591.333333
# 1    22889.166667
# 2    31755.500000
# 3    24059.500000
# 4    44775.666667
# dtype: float64

# %%
df.median()
# Out:
# age                   37.0
# fnlwgt            178356.0
# education.num         10.0
# capital.gain           0.0
# capital.loss           0.0
# hours.per.week        40.0
# dtype: float64

# %%
print(df.loc[:,'age'].median())
# Out:
# 37.0

# %%
df.mode()
# Out:
#     age workclass  fnlwgt education  education.num      marital.status  \
# 0  36.0   Private  123011   HS-grad            9.0  Married-civ-spouse
# 1   NaN       NaN  164190       NaN            NaN                 NaN
# 2   NaN       NaN  203488       NaN            NaN                 NaN
#
#        occupation relationship   race   sex  capital.gain  capital.loss  \
# 0  Prof-specialty      Husband  White  Male           0.0           0.0
# 1             NaN          NaN    NaN   NaN           NaN           NaN
# 2             NaN          NaN    NaN   NaN           NaN           NaN
#
#    hours.per.week native.country income
# 0            40.0  United-States  <=50K
# 1             NaN            NaN    NaN
# 2             NaN            NaN    NaN

# %%
df.std()
# Out:
# age                   13.640433
# fnlwgt            105549.977697
# education.num          2.572720
# capital.gain        7385.292085
# capital.loss         402.960219
# hours.per.week        12.347429
# dtype: float64

# %%
print(df.loc[:,'age'].std())
# Out:
# 13.640432553581118

# %%
df.var()
# Out:
# age               1.860614e+02
# fnlwgt            1.114080e+10
# education.num     6.618890e+00
# capital.gain      5.454254e+07
# capital.loss      1.623769e+05
# hours.per.week    1.524590e+02
# dtype: float64

# %%
print(df.loc[:,'age'].var())
# Out:
# 186.0614002487955

# %%
from scipy.stats import iqr

# %%
iqr(df['age'])
# Out:
# 20.0

# %%
print(df.skew())
# Out:
# age                0.558743
# fnlwgt             1.446980
# education.num     -0.311676
# capital.gain      11.953848
# capital.loss       4.594629
# hours.per.week     0.227643
# dtype: float64

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  education.num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital.status      occupation relationship   race    sex  \
# ...

# %%
grouped_summary = df.groupby('age')['income'].describe()
grouped_summary
# Out:
#     count unique    top freq
# age
# 17    395      1  <=50K  395
# 18    550      1  <=50K  550
# 19    712      2  <=50K  710
# 20    753      1  <=50K  753
# 21    720      2  <=50K  717
# 22    765      2  <=50K  752
# 23    877      2  <=50K  865
# 24    798      2  <=50K  767
# 25    841      2  <=50K  788
# 26    785      2  <=50K  722
# 27    835      2  <=50K  754
# 28    867      2  <=50K  748
# 29    813      2  <=50K  679
# 30    861      2  <=50K  690
# 31    888      2  <=50K  705
# 32    828      2  <=50K  639
# 33    875      2  <=50K  684
# 34    886      2  <=50K  643
# 35    876      2  <=50K  659
# 36    898      2  <=50K  635
# 37    858      2  <=50K  566
# 38    827      2  <=50K  545
# 39    816      2  <=50K  538
# 40    794      2  <=50K  526
# 41    808      2  <=50K  529
# 42    780      2  <=50K  510
# 43    770      2  <=50K  497
# 44    724      2  <=50K  443
# 45    734      2  <=50K  446
# 46    737      2  <=50K  445
# ..    ...    ...    ...  ...
# ...

# %% [markdown]
# # Part 2 Iris dataset

# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
print(df.shape)
# Out:
# (150, 6)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB
# None

# %%
df.mean()
# Out:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.752000
# PetalWidthCm      1.198667
# dtype: float64

# %%
df.loc[:,'PetalLengthCm'].mean()
# Out:
# 3.752000000000003

# %%
df.median()
# Out:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
df.loc[:,'PetalLengthCm'].median()
# Out:
# 4.35

# %%
df.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# 5      6            NaN           NaN            NaN           NaN
# 6      7            NaN           NaN            NaN           NaN
# 7      8            NaN           NaN            NaN           NaN
# 8      9            NaN           NaN            NaN           NaN
# 9     10            NaN           NaN            NaN           NaN
# 10    11            NaN           NaN            NaN           NaN
# 11    12            NaN           NaN            NaN           NaN
# 12    13            NaN           NaN            NaN           NaN
# ...

# %%
df.std()
# Out:
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.776760
# PetalWidthCm      0.763161
# dtype: float64

# %%
df.var()
# Out:
# Id               1887.500000
# SepalLengthCm       0.685694
# SepalWidthCm        0.188004
# PetalLengthCm       3.156875
# PetalWidthCm        0.582414
# dtype: float64

# %%
df.skew()
# Out:
# Id               0.000000
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.296313
# PetalWidthCm    -0.104997
# dtype: float64

# %%
print(df.loc[:,'PetalLengthCm'].std())
# Out:
# 1.7767597383397769

# %%
print(df.loc[:,'PetalLengthCm'].var())
# Out:
# 3.1568751677852327

# %%
print(df.loc[:,'PetalLengthCm'].skew())
# Out:
# -0.2963130906832654

# %%
print(df.loc[:,'PetalLengthCm'].mode())
# Out:
# 0    1.5
# dtype: float64

# %%
from scipy.stats import iqr

# %%
iqr(df['PetalLengthCm'])
# Out:
# 3.4999999999999996

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000      150.00000    150.000000
# mean    75.500000       5.843333      3.054000        3.75200      1.198667
# std     43.445368       0.828066      0.433594        1.77676      0.763161
# min      1.000000       4.300000      2.000000        0.00000      0.100000
# 25%     38.250000       5.100000      2.800000        1.60000      0.300000
# 50%     75.500000       5.800000      3.000000        4.35000      1.300000
# 75%    112.750000       6.400000      3.300000        5.10000      1.800000
# max    150.000000       7.900000      4.400000        6.90000      2.500000

# %%
df.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000      150.00000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000        3.75200      1.198667
# std      43.445368       0.828066      0.433594        1.77676      0.763161
# min       1.000000       4.300000      2.000000        0.00000      0.100000
# 25%      38.250000       5.100000      2.800000        1.60000      0.300000
# 50%      75.500000       5.800000      3.000000        4.35000      1.300000
# 75%     112.750000       6.400000      3.300000        5.10000      1.800000
# max     150.000000       7.900000      4.400000        6.90000      2.500000
#
#             Species
# count           150
# ...
